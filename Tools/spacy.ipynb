# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install spacy
#!python -m spacy download en_core_web_sm

# %%
import spacy
NLP = spacy.load("en_core_web_sm")
doc = NLP("Hi my name is mak")
doc
# Out:
# Hi my name is mak

# %%
text = "We were all out at the zoo one day, I was doing some acting, walking on the railing of the gorilla exhibit. I fell in. Everyone screamed and Tommy jumped in after me, forgetting that he had blueberries in his front pocket. The gorillas just went wild."

doc = NLP(text)

for i in doc.sents:
    print(">", i,'....', i.start, i.end)
# Out:
# > We were all out at the zoo one day, I was doing some acting, walking on the railing of the gorilla exhibit. .... 0 25
# > I fell in. .... 25 29
# > Everyone screamed and Tommy jumped in after me, forgetting that he had blueberries in his front pocket. .... 29 48
# > The gorillas just went wild. .... 48 54

# %%
# noun_chunks: phrases that have a noun as their head (العبارات التي لها اسما في البدايه)

text = "Steve Jobs and Steve Wozniak incorporated Apple Computer on January 3, 1977, in Cupertino, California."
doc = NLP(text)
for i in doc.noun_chunks:
    print(i.text)
print('#####################################################')
text1= 'Autonomous cars shift insurance liability toward manufacturers'
doc1= NLP(text1)
for chunk in doc1.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)
# Out:
# Steve Jobs
# Steve Wozniak
# Apple Computer
# January
# Cupertino
# California
# #####################################################
# Autonomous cars cars nsubj shift
# insurance liability liability dobj shift
# manufacturers manufacturers pobj toward

# %%
#Entities:  companies, locations, organizations and products
text = "Steve jobs and Steve Wozniak incorporated Apple Computer on January 3, 1977, in Cupertino, California."
doc = NLP(text)
for ent in doc.ents:
    print(ent.text,'....', ent.label_)
# Out:
# Steve .... PERSON
# Steve Wozniak .... PERSON
# Apple Computer .... ORG
# January 3, 1977 .... DATE
# Cupertino .... GPE
# California .... GPE

# %%
import pandas as pd
text = "Hi my name is mohammad"
doc = NLP(text)
print(doc,'\n')
print(doc[1],'\n')
print(doc[1],doc[1].pos_,'\n')
print(doc[1],doc[1].lemma_,'\n')

print(doc[1],spacy.explain(doc[1].pos_),'\n')

print(doc[1],doc[1].is_stop)
# Out:
# Hi my name is mohammad
#
# my
#
# my DET
#
# my -PRON-
#
# my determiner
#
# my True

# %%
import pandas as pd
text = "Hi my name is mohammad"
doc = NLP(text)


cols = ("text", "lemma", "POS", "explain", "stopword")
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df = pd.DataFrame(rows, columns=cols)
    
df
# Out:
#        text     lemma   POS       explain  stopword
# 0        Hi        hi  INTJ  interjection     False
# 1        my    -PRON-   DET    determiner      True
# 2      name      name  NOUN          noun      True
# 3        is        be   AUX     auxiliary      True
# 4  mohammad  mohammad  NOUN          noun     False

# %%
print(doc[1].text, doc[1].lemma_, doc[1].pos_)
# Out:
# my -PRON- DET
